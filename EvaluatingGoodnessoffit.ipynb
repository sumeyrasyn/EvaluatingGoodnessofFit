# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model
import statsmodels.formula.api as smf


# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

import warnings
warnings.filterwarnings(action="ignore")

                        
df = pd.read_csv("https://djl-lms-assets.s3.eu-central-1.amazonaws.com/datasets/weatherHistory.csv")
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain            9.472
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain            9.356
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain            9.378
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain            8.289
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain            8.756
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     7.389     0.890             14.120
# 1                     7.228     0.860             14.265
# 2                     9.378     0.890              3.928
# 3                     5.944     0.830             14.104
# 4                     6.978     0.830             11.045
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                 251.000           15.826       0.000              1015.130
# ...

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.isnull().sum()/len(df)*100
# Out:
# Formatted Date             0.000
# Summary                    0.000
# Precip Type                0.536
# Temperature (C)            0.000
# Apparent Temperature (C)   0.000
# Humidity                   0.000
# Wind Speed (km/h)          0.000
# Wind Bearing (degrees)     0.000
# Visibility (km)            0.000
# Loud Cover                 0.000
# Pressure (millibars)       0.000
# Daily Summary              0.000
# dtype: float64

# %%
df["Precip Type"].dropna()
# Out:
# 0        rain
# 1        rain
# 2        rain
# 3        rain
# 4        rain
#          ...
# 96448    rain
# 96449    rain
# 96450    rain
# 96451    rain
# 96452    rain
# Name: Precip Type, Length: 95936, dtype: object

# %%
df["Temperature"]= (df["Temperature (C)"]-df["Apparent Temperature (C)"])
from sklearn import linear_model

Y = df['Temperature']
X = df[['Humidity','Wind Speed (km/h)' ]]

lrm = linear_model.LinearRegression()
lrm.fit(X, Y)

print('Değişkenler: \n', lrm.coef_)
print('Sabit değer (bias): \n', lrm.intercept_)
# Out:
# Değişkenler:
#  [3.02918594 0.11929075]
# Sabit değer (bias):
#  -2.4381054151877244

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
sonuclar = sm.OLS(Y, X).fit()
sonuclar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Temperature   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):               0.00
# Time:                        17:39:22   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
df['h_w'] = df["Humidity"] * df['Wind Speed (km/h)']
Y = df['Temperature']
X = df[['Humidity','Wind Speed (km/h)','h_w']]

X = sm.add_constant(X)

sonuclar = sm.OLS(Y, X).fit()
sonuclar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Temperature   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                 1.666e+04
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):               0.00
# Time:                        17:39:22   Log-Likelihood:            -1.6669e+05
# No. Observations:               96453   AIC:                         3.334e+05
# Df Residuals:                   96449   BIC:                         3.334e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 2. modelin R-squared değeri yükseldi. adj.R-squared değerine baktığımda garip bir artış durumu söz konusu değil. p değerlerini inceldiğimde 1. ve 2. modelde var olan özellikler hedef değişkeni açıklama da anlamlı. AIC ve BIC değerleri ilk  modele göre 2. modelde daha küçük. Bu değerlerin olabildiğince küçük olmasını istiyoruz. Fakat R square değerimiz hala çok düşük. İyi bir model hala elde edemedik.
